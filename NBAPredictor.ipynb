# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

#load individual csv into one large df

MainDF = pd.concat(map(pd.read_csv, ['ATLData.csv', 'BOSData.csv', 'BRKData.csv', 'CHAData.csv', 'CHIData.csv', 'CHOData.csv'
                       , 'CLEData.csv', 'DALData.csv', 'DALData.csv', 'DENData.csv', 'DETData.csv', 'GSWData.csv', 'HOUData.csv'
                       , 'INDData.csv', 'KCKData.csv', 'LALData.csv', 'MEMData.csv', 'MIAData.csv', 'MILData.csv',
                       'MINData.csv', 'NJNData.csv', 'NOHData.csv', 'NOPData.csv', 'NYKData.csv', 'OKCData.csv',
                       'ORLData.csv', 'PHIData.csv', 'PHOData.csv', 'PORData.csv', 'SACData.csv', 'SASData.csv',
                       'SDCData.csv', 'SEAData.csv', 'TORData.csv', 'UTAData.csv', 'VANData.csv', 'WASData.csv',
                       'WSBData.csv']))

MainDF.to_csv('AllTeamData.csv', index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import tensorflow as tf
#       4 from tensorflow.keras.models import Sequential
#       5 from tensorflow.keras.layers import Dense, Dropout
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py:38
#      35 import sys as _sys
#      37 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 38 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      39 from tensorflow.python.tools import module_util as _module_util
#      40 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# ModuleNotFoundError: No module named 'tensorflow.python'
