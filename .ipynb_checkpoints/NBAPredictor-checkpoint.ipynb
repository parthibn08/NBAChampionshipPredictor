# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

#load individual csv into one large df

MainDF = pd.read_csv('AllTeamData.csv');

print(MainDF.head)
# Out:
# <bound method NDFrame.head of                             Name     MP    FG   FGA    FG%    3P   3PA    3P%  \
# 0          2023-24 Atlanta Hawks  242.1  43.0  92.5  0.465  13.7  37.7  0.364
# 1          2022-23 Atlanta Hawks  242.1  44.6  92.4  0.483  10.8  30.5  0.352
# 2          2021-22 Atlanta Hawks  240.3  41.5  88.3  0.470  12.9  34.4  0.374
# 3          2020-21 Atlanta Hawks  241.7  40.8  87.2  0.468  12.4  33.4  0.373
# 4          2019-20 Atlanta Hawks  243.0  40.6  90.6  0.449  12.0  36.1  0.333
# ...                          ...    ...   ...   ...    ...   ...   ...    ...
# 1259  1983-84 Washington Bullets  242.7  40.8  84.2  0.484   0.9   3.4  0.252
# 1260  1982-83 Washington Bullets  241.5  40.3  86.1  0.468   0.9   2.9  0.295
# 1261  1981-82 Washington Bullets  241.8  41.5  87.4  0.474   0.7   2.9  0.250
# 1262  1980-81 Washington Bullets  241.2  43.3  91.7  0.472   0.8   2.9  0.270
# 1263  1979-80 Washington Bullets  242.4  43.6  95.1  0.458   0.9   2.9  0.307
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import tensorflow as tf
#       4 from tensorflow.keras.models import Sequential
#       5 from tensorflow.keras.layers import Dense, Dropout
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py:38
#      35 import sys as _sys
#      37 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 38 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      39 from tensorflow.python.tools import module_util as _module_util
#      40 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# ModuleNotFoundError: No module named 'tensorflow.python'
